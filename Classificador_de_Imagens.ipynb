# %% [markdown]
# <a href="https://colab.research.google.com/github/carolrn11/Pyspark/blob/main/Classificador_de_Imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
from PIL import Image, ImageOps
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
model = load_model('/content/keras_model.h5')
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
classes = ['Fundo','Caderno','Marca Texto','Borracha']

# %%
foto = '/content/Borracha.jpg'
image = Image.open(foto)
size = (224, 224)
image = ImageOps.fit(image, size, Image.ANTIALIAS)

image_array = np.asarray(image)
normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
data[0] = normalized_image_array


prediction = model.predict(data)
indexVal = np.argmax(prediction)

imagem = cv2.imread(foto)
cv2_imshow(imagem)

print("A imagem da foto é uma " + classes[indexVal])
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7EFF0C807A50>
# A imagem da foto é uma Borracha
